# %%
import pandas as pd
import requests
import pandas as pd
import lxml
import html5lib

# %%
df = pd.read_csv('./../data/all_policies_by_state.csv', delimiter="^")

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index                                               Name  \
# 0         0     Zero-Emission Facilities Production Tax Credit
# 1         1  York Electric Cooperative - Dual Fuel Heat Pum...
# 2         2  Yellowstone Valley Electric Cooperative - Resi...
# 3         3  Yellowstone Valley Electric Cooperative - Ener...
# 4         4  Yampa Valley Electric Association - Renewable ...
# 5         5                Xcel Energy - Solar*Rewards Program
# 6         6                Xcel Energy - Solar*Rewards Program
# 7         7      Xcel Energy - Solar*Rewards Community Program
# 8         8  Xcel Energy - Small Business Energy Efficiency...
# 9         9  Xcel Energy - Residential Energy Efficiency Re...
# 10       10  Xcel Energy - Residential Energy Efficiency Re...
# 11       11  Xcel Energy - Residential Energy Efficiency Fi...
# 12       12  Xcel Energy - Residential and Hard-to-Reach St...
# 13       13    Xcel Energy - Renewable Development Fund Grants
# ...

# %%
df.to_excel('./../data/all_policies_by_state.xlsx')

# %%
df_read = pd.read_html(requests.get('http://programs.dsireusa.org/system/program/detail/21767').text)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-7cd8f24601b8> in <module>()
# ----> 1 df_read = pd.read_html(requests.get('http://programs.dsireusa.org/system/program/detail/21767').text)[0]
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     904                   thousands=thousands, attrs=attrs, encoding=encoding,
#     905                   decimal=decimal, converters=converters, na_values=na_values,
# --> 906                   keep_default_na=keep_default_na)
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     741             break
#     742     else:
# ...

# %%
with open(requests.get('http://programs.dsireusa.org/system/program/detail/21767').text, 'rt') as myfile:
    data = myfile.read().replace("<br>", '\n')


df = pd.read_html(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-126-cf329d77a10b> in <module>()
# ----> 1 with open(requests.get('http://programs.dsireusa.org/system/program/detail/21767').text, 'rt') as myfile:
#       2     data = myfile.read().replace("<br>", '\n')
#       3
#       4
#       5 df = pd.read_html(data)
#
# ...

# %%
df_co2 = pd.read_html('https://www.worldatlas.com/articles/us-states-by-carbon-dioxide-emissions-per-capita.html')[0]
df_co2.set_index(['Rank'], inplace=True)

# %%
df_co2.sort_values(['Jurisdiction'])
# Out:
#               Jurisdiction  CO2 emissions\nper capita\n(in metric tons)
# Rank
# 13                 Alabama                                        25.05
# 4                   Alaska                                        47.17
# 32                 Arizona                                        13.79
# 16                Arkansas                                        23.13
# 50              California                                         9.26
# 27                Colorado                                        16.95
# 46             Connecticut                                         9.77
# 31                Delaware                                        14.24
# 52    District of Columbia                                         4.55
# 40                 Florida                                        11.41
# 33                 Georgia                                        13.76
# 35                  Hawaii                                        12.82
# ...

# %%
df_co2.to_csv('./../data/co2.csv')
